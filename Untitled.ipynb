# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv('../data/Sensor_Weather_Data_Challenge.csv', index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#                          d1      d2      d3      d4      d5      d6      d7  \
# Time
# 2019-03-25 11:40:02  118.69  122.00  174.11  255.76  372.90  445.78  456.13
# 2019-03-25 11:41:02  118.71  122.10  174.09  254.72  371.33  444.66  456.81
# 2019-03-25 11:42:02  118.78  122.22  174.16  253.93  370.31  443.77  457.19
# 2019-03-25 11:43:02  118.82  122.34  174.18  253.00  369.00  442.90  457.58
# 2019-03-25 11:44:02  118.77  122.30  174.16  251.83  367.44  441.34  457.38
#
#                          d8      d9     d10       ...            d13    sky  \
# Time                                              ...
# 2019-03-25 11:40:02  327.28  261.67  220.01       ...         445.95 -30.82
# 2019-03-25 11:41:02  328.09  262.33  220.30       ...         447.16 -30.30
# 2019-03-25 11:42:02  329.17  263.24  220.68       ...         449.24 -27.92
# 2019-03-25 11:43:02  330.10  263.96  220.95       ...         450.82 -28.86
# ...

# %%
data.index
# Out:
# DatetimeIndex(['2019-03-25 11:40:02', '2019-03-25 11:41:02',
#                '2019-03-25 11:42:02', '2019-03-25 11:43:02',
#                '2019-03-25 11:44:02', '2019-03-25 11:45:02',
#                '2019-03-25 11:46:02', '2019-03-25 11:47:03',
#                '2019-03-25 11:48:03', '2019-03-25 11:49:03',
#                ...
#                '2019-05-10 18:41:51', '2019-05-10 18:42:51',
#                '2019-05-10 18:43:51', '2019-05-10 18:44:51',
#                '2019-05-10 18:45:51', '2019-05-10 18:46:51',
#                '2019-05-10 18:47:52', '2019-05-10 18:48:52',
#                '2019-05-10 18:49:52', '2019-05-10 18:50:52'],
#               dtype='datetime64[ns]', name='Time', length=37286, freq=None)

# %%
data.index.min()
# Out:
# '2019-03-25 11:40:02'

# %%
data.shape
# Out:
# (37286, 22)

# %%
data.d1[0:100].plot()

# %%
data.iloc[0:100, 0:13].plot()

# %%
day = data['2019-03-27':'2019-03-28']

# %%
sns.set(rc={'figure.figsize':(11, 4)})

# %%
day.iloc[:,0:5].plot(linewidth = 0.5)

# %%
sns.heatmap(day.iloc[:,0:1])

# %%
day.iloc[:,0:1].pivot(index = 'd1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-15de224b8f84> in <module>
# ----> 1 day.iloc[:,0:1].pivot(index = 'd1')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5192         """
#    5193         from pandas.core.reshape.reshape import pivot
# -> 5194         return pivot(self, index=index, columns=columns, values=values)
#    5195
#    5196     _shared_docs['pivot_table'] = """
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in pivot(self, index, columns, values)
#     398         cols = [columns] if index is None else [index, columns]
#     399         append = index is None
# --> 400         indexed = self.set_index(cols, append=append)
#     401     else:
#     402         if index is None:
#
# ...

# %%
sns.heatmap(day.iloc[:, 0:13].transpose())

# %%
def getdata(date = '2019-03-25'):
    day = {}
    day = data[date]
